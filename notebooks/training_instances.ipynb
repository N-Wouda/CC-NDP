# %%
# %cd ..
# Out:
# C:\Projects\CC-NDP

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = ['svg']

# %%
from contextlib import suppress

import matplotlib as mpl
from matplotlib.transforms import Bbox
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
)
from sklearn.preprocessing import OneHotEncoder

from src.classes import Result, RootResult, ProblemData, FORMULATIONS

# %%
# For final compilation
mpl.rcParams["text.usetex"] = True
plt.style.use("grayscale")

# %% [markdown]
# # Training instances: analysis and model formulation

# %%
experiments = pd.read_csv("instances/train/instances.csv", index_col="name")
experiments["data"] = experiments.apply(
    lambda r: ProblemData.from_file(f"instances/train/{r.name}.ndp"), axis=1
)
experiments.head()
# Out:
#                    num_nodes  num_arcs  num_commodities  num_scenarios  seed  \
# name
# train-19-1-60-32          20        60                1             32    19
# train-19-1-60-64          20        60                1             64    19
# train-19-1-60-128         20        60                1            128    19
# train-19-1-60-256         20        60                1            256    19
# train-19-1-90-32          20        90                1             32    19
#
#                                                                 data
# name
# train-19-1-60-32   ProblemData\n      # nodes: 20\n       # arcs:...
# train-19-1-60-64   ProblemData\n      # nodes: 20\n       # arcs:...
# train-19-1-60-128  ProblemData\n      # nodes: 20\n       # arcs:...
# train-19-1-60-256  ProblemData\n      # nodes: 20\n       # arcs:...
# train-19-1-90-32   ProblemData\n      # nodes: 20\n       # arcs:...

# %%
def make_formulation_perf_measures(df):
    df["run_time"] = df.result.apply(lambda res: res.run_time)
    df["num_iters"] = df.result.apply(lambda res: res.num_iters)
    df["objective"] = df.result.apply(lambda res: res.objective)

    return df


def make_formulation_dataframe(formulations):
    data = []
    results = []

    for experiment in experiments.index:
        data_loc = f"instances/train/{experiment}.ndp"
        data.append(
            dict(experiment=experiment, data=ProblemData.from_file(data_loc))
        )

        for formulation in formulations:
            with suppress(FileNotFoundError):
                res = Result.from_file(
                    f"out/train/{formulation}/{experiment}.json"
                )
                results.append(
                    dict(
                        experiment=experiment,
                        formulation=formulation,
                        result=res,
                    )
                )

    results = pd.DataFrame.from_records(results).join(
        experiments, on="experiment"
    )
    results = results.merge(pd.DataFrame.from_records(data), on="experiment")

    return make_formulation_perf_measures(results)

# %%
results = make_formulation_dataframe(FORMULATIONS)

# %%
pvt = pd.pivot(
    index="experiment", columns="formulation", values="run_time", data=results
)
pvt.style.highlight_min(subset=list(FORMULATIONS.keys()), axis=1)
# Out:
# <style type="text/css">
# #T_9b430_row0_col1, #T_9b430_row1_col1, #T_9b430_row2_col0, #T_9b430_row3_col1, #T_9b430_row4_col2, #T_9b430_row5_col1, #T_9b430_row6_col2, #T_9b430_row7_col1, #T_9b430_row8_col2, #T_9b430_row9_col1, #T_9b430_row10_col1, #T_9b430_row11_col1, #T_9b430_row12_col2, #T_9b430_row13_col1, #T_9b430_row14_col3, #T_9b430_row15_col3, #T_9b430_row16_col2, #T_9b430_row17_col2, #T_9b430_row18_col2, #T_9b430_row19_col3, #T_9b430_row20_col2, #T_9b430_row21_col2, #T_9b430_row22_col1, #T_9b430_row23_col1, #T_9b430_row24_col2, #T_9b430_row25_col3, #T_9b430_row26_col2, #T_9b430_row27_col2, #T_9b430_row28_col1, #T_9b430_row29_col1, #T_9b430_row30_col2, #T_9b430_row31_col2, #T_9b430_row32_col1, #T_9b430_row33_col3, #T_9b430_row34_col1, #T_9b430_row35_col2, #T_9b430_row36_col1, #T_9b430_row37_col2, #T_9b430_row38_col3, #T_9b430_row39_col1, #T_9b430_row40_col3, #T_9b430_
b430_row172_col1, #T_9b430_row173_col2, #T_9b430_row174_col3, #T_9b430_row175_col3, #T_9b430_row176_col3, #T_9b430_row177_col2, #T_9b430_row178_col2, #T_9b430_row179_col2, #T_9b430_row180_col1, #T_9b430_row181_col3, #T_9b430_row182_col3, #T_9b430_row183_col2, #T_9b430_row184_col2, #T_9b430_row185_col2, #T_9b430_row186_co ...
#   background-color: yellow;
# }
# </style>
# <table id="T_9b430">
#   <thead>
#     <tr>
#       <th class="index_name level0" >formulation</th>
#       <th id="T_9b430_level0_col0" class="col_heading level0 col0" >BB</th>
#       <th id="T_9b430_level0_col1" class="col_heading level0 col1" >FlowMIS</th>
#       <th id="T_9b430_level0_col2" class="col_heading level0 col2" >MIS</th>
#       <th id="T_9b430_level0_col3" class="col_heading level0 col3" >SNC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >experiment</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b430_level0_row0" class="row_heading level0 row0" >train-101-1-120-128</th>
#       <td id="T_9b430_row0_col0" class="data row0 col0" >1.687227</td>
#       <td id="T_9b430_row0_col1" class="data row0 col1" >0.886110</td>
#       <td id="T_9b430_row0_col2" class="data row0 col2" >1.685256</td>
#       <td id="T_9b430_row0_col3" class="data row0 col3" >1.888843</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row1" class="row_heading level0 row1" >train-101-1-120-256</th>
#       <td id="T_9b430_row1_col0" class="data row1 col0" >5.316856</td>
#       <td id="T_9b430_row1_col1" class="data row1 col1" >2.364592</td>
#       <td id="T_9b430_row1_col2" class="data row1 col2" >2.704601</td>
#       <td id="T_9b430_row1_col3" class="data row1 col3" >3.227460</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row2" class="row_heading level0 row2" >train-101-1-120-32</th>
#       <td id="T_9b430_row2_col0" class="data row2 col0" >0.311814</td>
#       <td id="T_9b430_row2_col1" class="data row2 col1" >0.535666</td>
#       <td id="T_9b430_row2_col2" class="data row2 col2" >0.420085</td>
#       <td id="T_9b430_row2_col3" class="data row2 col3" >0.475127</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row3" class="row_heading level0 row3" >train-101-1-120-64</th>
#       <td id="T_9b430_row3_col0" class="data row3 col0" >0.478328</td>
#       <td id="T_9b430_row3_col1" class="data row3 col1" >0.367131</td>
#       <td id="T_9b430_row3_col2" class="data row3 col2" >0.411768</td>
#       <td id="T_9b430_row3_col3" class="data row3 col3" >0.439902</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row4" class="row_heading level0 row4" >train-101-1-180-128</th>
#       <td id="T_9b430_row4_col0" class="data row4 col0" >18.207306</td>
#       <td id="T_9b430_row4_col1" class="data row4 col1" >2.856867</td>
#       <td id="T_9b430_row4_col2" class="data row4 col2" >2.317888</td>
#       <td id="T_9b430_row4_col3" class="data row4 col3" >2.357097</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row5" class="row_heading level0 row5" >train-101-1-180-256</th>
#       <td id="T_9b430_row5_col0" class="data row5 col0" >18.539162</td>
#       <td id="T_9b430_row5_col1" class="data row5 col1" >3.504720</td>
#       <td id="T_9b430_row5_col2" class="data row5 col2" >4.550882</td>
#       <td id="T_9b430_row5_col3" class="data row5 col3" >5.235019</td>
#     </tr>
#     <tr>
#       <th id="T_9b430_level0_row6" class="row_heading level0 row6" >train-101-1-180-32</th>
#       <td id="T_9b430_row6_col0

# %%
results.experiment.groupby(results.formulation).count()  # num solved
# Out:
# formulation
# BB         154
# FlowMIS    209
# MIS        212
# SNC        217
# Name: experiment, dtype: int64

# %%
pvt.idxmin(axis=1).value_counts()  # solved fastest
# Out:
# FlowMIS    75
# MIS        68
# SNC        54
# BB         24
# Name: count, dtype: int64

# %%
def make_features(pvt, experiments):
    res = pvt.fillna(7200)
    res = res.join(experiments)

    X = np.zeros((len(res), 3))
    X[:, 0] = res.num_commodities
    X[:, 1] = res.num_arcs
    X[:, 2] = res.num_scenarios

    enc = OneHotEncoder(handle_unknown="ignore")
    enc.fit(np.array(list(FORMULATIONS.keys())).reshape(-1, 1))
    y = np.array(
        enc.transform(pvt.idxmin(axis=1).values.reshape(-1, 1)).todense()
    )

    return X, y


X_train, y_train = make_features(pvt, experiments)

# %%
clf = RandomForestClassifier(n_estimators=64, random_state=42)
clf = clf.fit(X_train, y_train)

# %%
clf.feature_importances_
# Out:
# array([0.47871362, 0.28005071, 0.24123568])

# %%
print(classification_report(y_train, clf.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        24
#            1       0.68      0.68      0.68        75
#            2       0.70      0.56      0.62        68
#            3       0.75      0.67      0.71        54
#
#    micro avg       0.72      0.65      0.68       221
#    macro avg       0.73      0.67      0.70       221
# weighted avg       0.72      0.65      0.68       221
#  samples avg       0.65      0.65      0.65       221
# C:\Users\niels\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(accuracy_score(y_train, clf.predict(X_train)))
# Out:
# 0.6515837104072398

# %%
test_experiments = pd.read_csv(
    "instances/test/instances.csv", index_col="name"
)
test_experiments["data"] = test_experiments.apply(
    lambda r: ProblemData.from_file(f"instances/test/{r.name}.ndp"), axis=1
)
test_experiments.head()
# Out:
#             group  correlation  num_nodes  num_arcs  num_commodities  \
# name
# r04-3-0-128   r04          0.0         10        60               10
# r04-3-0-256   r04          0.0         10        60               10
# r04-3-0-512   r04          0.0         10        60               10
# r04-3-0-16    r04          0.0         10        60               10
# r04-3-0-32    r04          0.0         10        60               10
#
#              num_scenarios                                               data
# name
# r04-3-0-128            128  ProblemData\n      # nodes: 10\n       # arcs:...
# r04-3-0-256            256  ProblemData\n      # nodes: 10\n       # arcs:...
# r04-3-0-512            512  ProblemData\n      # nodes: 10\n       # arcs:...
# r04-3-0-16              16  ProblemData\n      # nodes: 10\n       # arcs:...
# r04-3-0-32              32  ProblemData\n      # nodes: 10\n       # arcs:...

# %%
def make_formulation_perf_measures(df):
    df["run_time"] = df.result.apply(lambda res: res.run_time)
    df["num_iters"] = df.result.apply(lambda res: res.num_iters)
    df["objective"] = df.result.apply(lambda res: res.objective)

    return df


def make_formulation_dataframe(formulations):
    data = []
    results = []

    for experiment in test_experiments.index:
        data_loc = f"instances/test/{experiment}.ndp"
        data.append(
            dict(experiment=experiment, data=ProblemData.from_file(data_loc))
        )

        for formulation in formulations:
            with suppress(FileNotFoundError):
                res = Result.from_file(
                    f"out/new/{formulation}/{experiment}.json"
                )
                results.append(
                    dict(
                        experiment=experiment,
                        formulation=formulation,
                        result=res,
                    )
                )

    results = pd.DataFrame.from_records(results).join(
        experiments, on="experiment"
    )
    results = results.merge(pd.DataFrame.from_records(data), on="experiment")

    return make_formulation_perf_measures(results)

# %%
test_results = make_formulation_dataframe(FORMULATIONS)

# %%
test_pvt = pd.pivot(
    index="experiment",
    columns="formulation",
    values="run_time",
    data=test_results,
)

# %%
X_test, y_test = make_features(test_pvt, test_experiments)

# %%
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.08      0.07        25
#            1       0.34      0.22      0.27        67
#            2       0.20      0.19      0.19        69
#            3       0.16      0.22      0.18        32
#
#    micro avg       0.20      0.19      0.19       193
#    macro avg       0.19      0.18      0.18       193
# weighted avg       0.22      0.19      0.20       193
#  samples avg       0.19      0.19      0.19       193
# C:\Users\niels\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(accuracy_score(y_test, clf.predict(X_test)))
# Out:
# 0.19170984455958548
